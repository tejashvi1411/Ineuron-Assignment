# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
df=pd.read_csv("ibm.csv")

# %%
df[0:3]
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
#
#    DistanceFromHome      Education EducationField  EmployeeCount  \
# 0                 1        College  Life Sciences              1
# 1                 8  Below College  Life Sciences              1
# 2                 2        College          Other              1
#
#    EmployeeNumber  ... RelationshipSatisfaction StandardHours  \
# 0               1  ...                        1            80
# 1               2  ...                        4            80
# 2               4  ...                        2            80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear WorkLifeBalance  \
# 0                 0                  8                      0             Bad
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# ## Age Of Employees

# %%
sns.displot(data=df,x="Age",kde=True,color="lightgreen",aspect=10/6)

# %%
int(df["Age"].mean())
# Out:
# 36

# %% [markdown]
# Mean Age Of IBM Employee Is 36

# %% [markdown]
# Mean Age Distribution Of Employees Based On The Department They Work In:

# %%
sns.catplot(data=df,x="Department",y="Age",kind="point",color="lightgreen",aspect=10/6)

# %%
sns.catplot(data=df,x="Department",y="Age",kind="swarm",color="lightgreen",aspect=10/6)
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
x=int(df[df["Department"]=="Sales"]["Age"].mean())
print("Mean Age Of Employee Working In Sales Dept Is",x)
# Out:
# Mean Age Of Employee Working In Sales Dept Is 36

# %%
x=int(df[df["Department"]=="Research & Development"]["Age"].mean())
print("Mean Age Of Employee Working In Research & Development Dept Is",x)
# Out:
# Mean Age Of Employee Working In Research & Development Dept Is 37

# %%
x=int(df[df["Department"]=="Human Resources"]["Age"].mean())
print("Mean Age Of Employee Working In Human Resources Dept Is",x)
# Out:
# Mean Age Of Employee Working In Human Resources Dept Is 37

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="point",color="lightgreen",aspect=10/6)

# %%
sns.catplot(data=df,x="Gender",y="Age",kind="swarm",color="lightgreen",aspect=10/6)

# %%
x=int(df[df["Gender"]=="Male"]["Age"].mean())
print("Mean Age Of Male Employee Is",x)
x=int(df[df["Gender"]=="Female"]["Age"].mean())
print("Mean Age Of Female Employee Is",x)
# Out:
# Mean Age Of Male Employee Is 36
# Mean Age Of Female Employee Is 37

# %% [markdown]
# Distribution Of Age With Respect To Level & Field Of Education

# %%
sns.catplot(data=df,x="EducationField",y="Age",kind="swarm",color="lightgreen",aspect=10/6)
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\2192a\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=df,x="Education",y="Age",kind="swarm",color="lightgreen",aspect=10/6)
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 14.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\2192a\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=df,x="EducationField",y="Age",kind="bar",color="lightgreen",aspect=10/6)

# %%
sns.catplot(data=df,x="Education",y="Age",kind="bar",color="lightgreen",aspect=10/6)

# %%
sns.catplot(data=df,x="EducationField",y="Age",kind="swarm",color="black",hue="Education",aspect=10/6)
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 32.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\2192a\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 18.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Performance Of Employees With Respect To Age

# %%
sns.catplot(data=df,x="PerformanceRating",y="Age",kind="swarm",color="lightgreen",aspect=10/6)
# Out:
# C:\Users\2192a\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 12.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.catplot(data=df,x="PerformanceRating",y="Age",kind="point",color="lightgreen",aspect=10/6)

# %% [markdown]
# # Department

# %%
sns.catplot(data=df,x="Department",color="skyblue",kind="count",aspect=10/6)

# %%
sns.catplot(data=df,x="Department",color="skyblue",kind="count",aspect=10/6)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...
